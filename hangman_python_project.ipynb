# %% [markdown]
# <a href="https://colab.research.google.com/github/FaizBano/04_assignments/blob/main/hangman_python_project.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# Hangman Python Project

# %%
import random

word_list = ["python", "hangman", "challenge", "programming", "computer"]

def display_word(word, guessed_letters):
    display = ""
    for letter in word:
        if letter in guessed_letters:
            display += letter
        else:
            display += "_"
    return display

def play_game():
    word = random.choice(word_list)
    guessed_letters = set()
    attempts = 6

    print("WELCOME TO THE HANGMAN GAME 🎮\n")

    while attempts > 0:
        current_display = display_word(word, guessed_letters)
        print(f"Word: {current_display}")
        print(f"Guessed Letters: {' '.join(sorted(guessed_letters))}")
        print(f"Attempts Left: {attempts}")

        guess = input("Guess a letter: ").lower()

        if not guess.isalpha() or len(guess) != 1:
            print("❗ Please enter a single valid letter.\n")
            continue

        if guess in guessed_letters:
            print("⚠️ You've already guessed that letter.\n")
            continue

        guessed_letters.add(guess)

        if guess in word:
            print("✅ Very Good Guess 👏\n")
        else:
            print("❌ Bad attempt\n")
            attempts -= 1

        if "_" not in display_word(word, guessed_letters):
            print(f"🎉 Congratulations! You guessed the word: {word}\n")
            break
    else:
        print(f"😢 Game Over! The correct word was: {word}\n")

# Loop for "play again"
while True:
    play_game()
    play_again = input("Do you want to play again? (yes/no): ").lower()
    if play_again != "yes":
        print("🙏 Thanks for playing! Goodbye 🎉")
        break
# Out:
# WELCOME TO THE HANGMAN GAME 🎮
#
# Word: ___________
# Guessed Letters:
# Attempts Left: 6
# Guess a letter: p
# ✅ Very Good Guess 👏
#
# Word: p__________
# Guessed Letters: p
# Attempts Left: 6
# Guess a letter: y
# ❌ Bad attempt
#
# Word: p__________
# Guessed Letters: p y
# Attempts Left: 5
# Guess a letter: t
# ❌ Bad attempt
#
# Word: p__________
# Guessed Letters: p t y
# Attempts Left: 4
# Guess a letter: h
# ❌ Bad attempt
#
# Word: p__________
# Guessed Letters: h p t y
# Attempts Left: 3
# Guess a letter: o
# ✅ Very Good Guess 👏
#
# Word: p_o________
# Guessed Letters: h o p t y
# Attempts Left: 3
# Guess a letter: n
# ✅ Very Good Guess 👏
#
# Word: p_o______n_
# Guessed Letters: h n o p t y
# Attempts Left: 3
# Guess a letter: y
# ⚠️ You've already guessed that letter.
#
# Word: p_o______n_
# Guessed Letters: h n o p t y
# Attempts Left: 3
# Guess a letter: h
# ⚠️ You've already guessed that letter.
#
# Word: p_o______n_
# Guessed Letters: h n o p t y
# Attempts Left: 3
# ...
